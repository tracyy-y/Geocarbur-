# %% [markdown]
# # Ingestion de données

# %%
import os
import pandas
import geopandas
from datetime import datetime

# %%
# lire le fichier geojson des stations
gdf = geopandas.read_file("../data/station_abidjan_v1.geojson")

# %%
# afficher les données
display(gdf)
display(gdf.sample())
# Out:
#                    id                                    name  \
# 0      node/243778772  Station Service Shell Carrefour Duncan
# 1      node/729781766            Station Service Pétro Ivoire
# 2      node/773848817      Station Service Pétro Ivoire Angré
# 3      node/773848861             Station Service Shell Angré
# 4      node/775786955                        Corlay Riviera 3
# ..                ...                                     ...
# 318  node/11866244469                                     SIP
# 319  node/11904808382                                   Total
# 320  node/12059902041                                   Shell
# 321  node/12063738451                                Afriquia
# 322  node/12122258220                            Petro Ivoire
#
#                           operator  shop  \
# 0     Vivo Energy Côte d'Ivoire SA  None
# 1                  Pétro Ivoire SA   yes
# 2                  Pétro Ivoire SA  None
# 3     Vivo Energy Côte d'Ivoire SA  None
# 4          Corlay Côte d'Ivoire SA  None
# ..                             ...   ...
# 318  Société Ivoirienne de Pétrole  None
# 319                           None  None
# 320                           None  None
# 321                           None  None
# 322                           None  None
#
#                                        adresse                  geometry
# 0          Aghien;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.99745 5.37826)
# 1    Vieux Cocody;Cocody;Abidjan;Côte d'Ivoire  POINT (-4.00171 5.35252)
# 2           Angré;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.99095 5.40487)
# 3                                         None  POINT (-3.99048 5.40473)
# 4       Riviera 3;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.95992 5.35492)
# ..                                         ...                       ...
# 318                                       None  POINT (-4.00433 5.27852)
# 319                                       None  POINT (-3.96315 5.34249)
# 320                                       None  POINT (-3.98735 5.38477)
# 321                                       None  POINT (-3.86053 5.23127)
# 322                                       None  POINT (-3.94034 5.39732)
#
# [323 rows x 6 columns]
#                    id           name operator  shop adresse  \
# 298  node/10840041006  Station Shell     None  None    None
#
#                     geometry
# 298  POINT (-4.00587 5.4117)

# %%
# exploitation 
gdf.describe()
# Out:
#                       id   name                      operator shop  \
# count                323    302                           183   30
# unique               323    161                            28    4
# top     node/12122258220  Shell  Vivo Energy Côte d'Ivoire SA  yes
# freq                   1     31                            66   24
#
#                                adresse                     geometry
# count                               37                          323
# unique                              15                          323
# top     Yopougon;Abidjan;Côte d’Ivoire  POINT (-3.990483 5.4047311)
# freq                                12                            1

# %%
# renommer les colonnes
gdf_clean = gdf.rename(columns={
    "name": "nom",
    "operator": "operateur",

})

display(gdf.columns) 
display(gdf_clean)
# Out:
# Index(['id', 'name', 'operator', 'shop', 'adresse', 'geometry'], dtype='object')
#                    id                                     nom  \
# 0      node/243778772  Station Service Shell Carrefour Duncan
# 1      node/729781766            Station Service Pétro Ivoire
# 2      node/773848817      Station Service Pétro Ivoire Angré
# 3      node/773848861             Station Service Shell Angré
# 4      node/775786955                        Corlay Riviera 3
# ..                ...                                     ...
# 318  node/11866244469                                     SIP
# 319  node/11904808382                                   Total
# 320  node/12059902041                                   Shell
# 321  node/12063738451                                Afriquia
# 322  node/12122258220                            Petro Ivoire
#
#                          operateur  shop  \
# 0     Vivo Energy Côte d'Ivoire SA  None
# 1                  Pétro Ivoire SA   yes
# 2                  Pétro Ivoire SA  None
# 3     Vivo Energy Côte d'Ivoire SA  None
# 4          Corlay Côte d'Ivoire SA  None
# ..                             ...   ...
# 318  Société Ivoirienne de Pétrole  None
# 319                           None  None
# 320                           None  None
# 321                           None  None
# 322                           None  None
#
#                                        adresse                  geometry
# 0          Aghien;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.99745 5.37826)
# 1    Vieux Cocody;Cocody;Abidjan;Côte d'Ivoire  POINT (-4.00171 5.35252)
# 2           Angré;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.99095 5.40487)
# 3                                         None  POINT (-3.99048 5.40473)
# 4       Riviera 3;Cocody;Abidjan;Côte d'Ivoire  POINT (-3.95992 5.35492)
# ..                                         ...                       ...
# 318                                       None  POINT (-4.00433 5.27852)
# 319                                       None  POINT (-3.96315 5.34249)
# 320                                       None  POINT (-3.98735 5.38477)
# 321                                       None  POINT (-3.86053 5.23127)
# 322                                       None  POINT (-3.94034 5.39732)
#
# [323 rows x 6 columns]

# %%
#ajouter les colonnes villes_id et created_at
gdf_clean["ville_id"] = 1
gdf_clean["created_at"] = datetime.now()
display(gdf_clean.sample())
# Out:
#                  id                          nom               operateur  \
# 82  node/2899062488  Station Service Total Dokui  Total Côte d'Ivoire SA
#
#     shop adresse                  geometry  ville_id  \
# 82  None    None  POINT (-4.00629 5.40466)         1
#
#                    created_at
# 82 2025-03-26 21:20:08.579778

# %%
# nettoyer id et shop
gdf_clean["id"] = range(1,324)
gdf_clean["shop"] = gdf_clean["shop"].apply(
    lambda shop: True if shop=="yes" else False
)
display(gdf_clean.dtypes)
display(gdf_clean.sample())
# Out:
# id                     int64
# nom                   object
# operateur             object
# shop                    bool
# adresse               object
# geometry            geometry
# ville_id               int64
# created_at    datetime64[us]
# dtype: object
#       id                             nom                operateur   shop  \
# 104  105  Station Service Corlay Plateau  Corlay Côte d'Ivoire SA  False
#
#     adresse                  geometry  ville_id                 created_at
# 104    None  POINT (-4.02217 5.32434)         1 2025-03-26 21:20:08.579778

# %%
# exporter gdf_clean
gdf_clean.to_file("../data/result/stations.shp")
gdf_clean.to_file("../data/result/stations.geojson")
# Out:
# C:\Users\USER\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyogrio\raw.py:723: RuntimeWarning: Field created_at create as date field, though DateTime requested.
#   ogr_write(
